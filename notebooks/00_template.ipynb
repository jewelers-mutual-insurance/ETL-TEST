# %%
# change notebook path to top-level for writing import statements for modules in src 
import sys
sys.path.append("..")

# Enable Autoreload of Modules, so kernal doesn't have to be restarted after code changes
# %load_ext autoreload
# %autoreload 2

# %%
# use dotenv library to import secrets from .env file
import os
from dotenv import load_dotenv, find_dotenv
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)
# var = os.environ.get("VAR")
